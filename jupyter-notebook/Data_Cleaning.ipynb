# %%
import pandas as pd

# %%
df = pd.read_excel('D:\\Py files\\AI-project-01\\dataset-AI_project_01.xlsx')

# %%
 df.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  glucose  smoke  \
# 0  14631       2     166      90    120     80            1        1      0
# 1  19574       2     140      58    140     80            1        1      0
# 2  19758       1     160      74    120     80            1        1      1
# 3  16664       2     130      93    130     80            1        1      1
# 4  15215       2     172      71    160    120            3        3      1
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       0
# 2     0       1       0
# 3     0       1       0
# 4     1       0       1

# %%
df.tail(10)
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  glucose  smoke  \
# 95   14610       2     164      65    120     80            1        1      0
# 96   20601       2     181      90    140    100            1        1      0
# 97   18326       1     158      68     90     60            1        1      0
# 98   20929       1     167      84    160    100            1        1      0
# 99   21150       1     160      72    150     80            1        1      0
# 100  21277       1     162      77    110     70            1        1      0
# 101  16723       1     157      94    120     80            2        2      0
# 102  21276       1     164      71    120     80            1        1      0
# 103  18922       1     165      60    160     90            3        2      0
# 104  20527       1     175      80    120     80            1        1      0
#
#      alco  active  cardio
# 95      0       1       0
# 96      0       1       1
# 97      0       1       0
# ...

# %%
df.head(10)
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  glucose  smoke  \
# 0  14631       2     166      90    120     80            1        1      0
# 1  19574       2     140      58    140     80            1        1      0
# 2  19758       1     160      74    120     80            1        1      1
# 3  16664       2     130      93    130     80            1        1      1
# 4  15215       2     172      71    160    120            3        3      1
# 5  19834       1     158      68    120     80            1        1      0
# 6  17740       1     158      74    120     80            2        2      0
# 7  15383       2     170      69    120     80            1        1      0
# 8  16845       2     160      60    150     90            1        1      0
# 9  22705       1     158      84    120     80            2        2      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       0
# 2     0       1       0
# 3     0       1       0
# ...

# %%
df.columns
# Out:
# Index(['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol',
#        'glucose', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
df.shape
# Out:
# (105, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          105 non-null    int64
#  1   gender       105 non-null    int64
#  2   height       105 non-null    int64
#  3   weight       105 non-null    int64
#  4   ap_hi        105 non-null    int64
#  5   ap_lo        105 non-null    int64
#  6   cholesterol  105 non-null    int64
#  7   glucose      105 non-null    int64
#  8   smoke        105 non-null    int64
#  9   alco         105 non-null    int64
#  10  active       105 non-null    int64
#  11  cardio       105 non-null    int64
# dtypes: int64(12)
# memory usage: 10.0 KB

# %%
df.columns
# Out:
# Index(['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol',
#        'glucose', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df['age'].value_counts(dropna=False)
# Out:
# 19011    2
# 14631    1
# 19574    1
# 16657    1
# 17423    1
#         ..
# 22148    1
# 14492    1
# 21257    1
# 22493    1
# 20527    1
# Name: age, Length: 104, dtype: int64

# %%
df.describe()
# Out:
#                 age      gender      height      weight       ap_hi  \
# count    105.000000  105.000000  105.000000  105.000000  105.000000
# mean   19513.580952    1.295238  162.714286   75.247619  128.142857
# std     2411.131149    0.458337    8.959003   18.607164   17.994352
# min    14370.000000    1.000000  130.000000   41.000000   80.000000
# 25%    17740.000000    1.000000  158.000000   65.000000  120.000000
# 50%    19715.000000    1.000000  162.000000   74.000000  120.000000
# 75%    21277.000000    2.000000  167.000000   84.000000  140.000000
# max    23661.000000    2.000000  186.000000  200.000000  180.000000
#
#             ap_lo  cholesterol     glucose       smoke        alco  \
# count  105.000000   105.000000  105.000000  105.000000  105.000000
# mean    80.695238     1.447619    1.352381    0.095238    0.038095
# std     11.353688     0.746543    0.679097    0.294951    0.192344
# min     30.000000     1.000000    1.000000    0.000000    0.000000
# ...

# %%
df_subset = df.copy()

# %%
df_subset.head(20)
# Out:
#       age  gender  height  weight  ap_hi  ap_lo  cholesterol  glucose  smoke  \
# 0   14631       2     166      90    120     80            1        1      0
# 1   19574       2     140      58    140     80            1        1      0
# 2   19758       1     160      74    120     80            1        1      1
# 3   16664       2     130      93    130     80            1        1      1
# 4   15215       2     172      71    160    120            3        3      1
# 5   19834       1     158      68    120     80            1        1      0
# 6   17740       1     158      74    120     80            2        2      0
# 7   15383       2     170      69    120     80            1        1      0
# 8   16845       2     160      60    150     90            1        1      0
# 9   22705       1     158      84    120     80            2        2      0
# 10  16320       2     168      75    120     80            1        1      0
# ...

# %%
cleaned = df_subset.head(20).dropna()

# %%
cleaned
# Out:
#       age  gender  height  weight  ap_hi  ap_lo  cholesterol  glucose  smoke  \
# 0   14631       2     166      90    120     80            1        1      0
# 1   19574       2     140      58    140     80            1        1      0
# 2   19758       1     160      74    120     80            1        1      1
# 3   16664       2     130      93    130     80            1        1      1
# 4   15215       2     172      71    160    120            3        3      1
# 5   19834       1     158      68    120     80            1        1      0
# 6   17740       1     158      74    120     80            2        2      0
# 7   15383       2     170      69    120     80            1        1      0
# 8   16845       2     160      60    150     90            1        1      0
# 9   22705       1     158      84    120     80            2        2      0
# 10  16320       2     168      75    120     80            1        1      0
# ...

# %%
cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          20 non-null     int64
#  1   gender       20 non-null     int64
#  2   height       20 non-null     int64
#  3   weight       20 non-null     int64
#  4   ap_hi        20 non-null     int64
#  5   ap_lo        20 non-null     int64
#  6   cholesterol  20 non-null     int64
#  7   glucose      20 non-null     int64
#  8   smoke        20 non-null     int64
#  9   alco         20 non-null     int64
#  10  active       20 non-null     int64
#  11  cardio       20 non-null     int64
# dtypes: int64(12)
# memory usage: 2.0 KB

# %%
df_height = df['height']

# %%
df_height
# Out:
# 0      166
# 1      140
# 2      160
# 3      130
# 4      172
#       ...
# 100    162
# 101    157
# 102    164
# 103    165
# 104    175
# Name: height, Length: 105, dtype: int64

# %%
df_height.shape
# Out:
# (105,)

# %%
df.columns = df.columns.str.upper()

# %%
df.columns
# Out:
# Index(['AGE', 'GENDER', 'HEIGHT', 'WEIGHT', 'AP_HI', 'AP_LO', 'CHOLESTEROL',
#        'GLUCOSE', 'SMOKE', 'ALCO', 'ACTIVE', 'CARDIO'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
cleaned['weight'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
cleaned[cleaned['weight'] > 80]
# Out:
#       age  gender  height  weight  ap_hi  ap_lo  cholesterol  glucose  smoke  \
# 0   14631       2     166      90    120     80            1        1      0
# 3   16664       2     130      93    130     80            1        1      1
# 9   22705       1     158      84    120     80            2        2      0
# 16  22531       2     164      81    150     90            2        2      0
#
#     alco  active  cardio
# 0      0       1       0
# 3      0       1       0
# 9      0       1       1
# 16     0       1       1

# %%
cleaned["age"] = round(cleaned["age"] / 365)

# %%
cleaned.boxplot(column='weight', by='age')
# Out:
# <AxesSubplot:title={'center':'weight'}, xlabel='age'>

# %%
cleaned.plot(kind='scatter', x='height', y= 'weight', rot=45)
# Out:
# <AxesSubplot:xlabel='height', ylabel='weight'>
